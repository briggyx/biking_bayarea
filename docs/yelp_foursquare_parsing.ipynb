# %%
import requests
import pandas as pd
import pickle
import json
import os
import keyring

import sys

sys.path.append('..\\src')
import fsq_yelp_parsing

# %% [markdown]
# # Foursquare & Yelp APIs

# %% [markdown]
# Since a typical 5-minute bike ride covers about 1000-1100 meters, I'll look within a 1000-meter radius around bike stations and arrange the results by distance.
#
# Imagine a scenario where someone is planning a day out with friends, biking between places. They'll start from a meeting spot reached by public transport. They're looking for places with activities suitable for groups, like artsy spots, outdoor fun, places to eat, and activities that are not too strenuous.

# %%
# UNPICKLE CITYBIKES DF
with open('../data/citybikes_filled_df.pickle', 'rb') as df:
    citybikes_df = pickle.load(df)

citybikes_df.head(5)
# Out:
#                          name                                id  \
# 0     Harmon St at Adeline St  d0e8f4f1834b7b33a3faf8882f567ab8
# 1  Fountain Alley at S 2nd St  983514094dd808b1604da2dcfc2d09af
# 2            Oak St at 1st St  da17603652106fda93da4e255a5b0a22
# 3             Bestor Art Park  7a21c92b3b4cd2f7759107b4fdebf869
# 4       5th St at Virginia St  ce34d38fb230a23c1ced12d1e16df294
#
#                      timestamp   longitude   latitude slots free_bikes  \
# 0  2024-04-02T18:29:27.066000Z -122.270582  37.849735    15          9
# 1  2024-04-02T18:29:26.582000Z -121.889277  37.336188    11          8
# 2  2024-04-02T18:29:27.044000Z  -121.88109  37.322125    23         14
# 3  2024-04-02T18:29:26.797000Z -121.874119  37.323678    15         12
# 4  2024-04-02T18:29:26.971000Z  -121.87712  37.325998    27         19
#
#   empty_slots has_ebikes ebikes            payment renting returning
# 0           6       True      0  [key, creditcard]       1         1
# 1           3       True      6  [key, creditcard]       1         1
# 2           9       True      7  [key, creditcard]       1         1
# 3           3       True      3  [key, creditcard]       1         1
# 4           7       True     12  [key, creditcard]       1         1

# %%
fsq_api_key = keyring.get_password("foursquare", "fsq_api_key") # $200 free credit for API usage granted on the first of every month
yelp_api_key = keyring.get_password("yelp", "yelp_api_key") # 5000 API calls daily limit, resets at midnight

# %%
url = 'https://api.foursquare.com/v3/places/search'
params = {'ll': '37.849735,-122.270582', 'radius': '1000', 'limit': '3', 'categories' : '13000,10000,16000,19042,19043,19046,19050,19054', 'sort' : 'distance'} #13000 is the category label for dining & drinking on foursquare, 10000 =  arts & entertainment, 16000 = landmarks & outdoors, 19042 = bus station, 19043 = bus stop, 19046 = metro station, 19050 = tram station, 19054 = public transportation 
headers = {'Accept': 'application/json', 'Authorization': f'{fsq_api_key}'}  

response = requests.request("GET", url, params=params, headers=headers) # the max limit for results per query is 50, the default is 20
print('status:', response.status_code)
res1 = response.json()
print(json.dumps(res1, indent=4))
# Out:
# status: 200
# {
#     "results": [
#         {
#             "fsq_id": "4b3fc82cf964a520a1ae25e3",
#             "categories": [
#                 {
#                     "id": 13303,
#                     "name": "Mexican Restaurant",
#                     "short_name": "Mexican",
#                     "plural_name": "Mexican Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/mexican_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "chains": [],
#             "closed_bucket": "Unsure",
#             "distance": 33,
#             "geocodes": {
#                 "main": {
#                     "latitude": 37.850052,
#                     "longitude": -122.270523
#                 },
#                 "roof": {
#                     "latitude": 37.850052,
#                     "longitude": -122.270523
#                 }
#             },
#             "link": "/v3/places/4b3fc82cf964a520a1ae25e3",
#             "location": {
#                 "address": "3221 Adeline St",
#                 "census_block": "060014239011019",
#                 "country": "US",
#                 "cross_street": "Alactraz St.",
#                 "dma": "San Francisco-Oakland-San Jose",
#                 "formatted_address": "3221 Adeline St (Alactraz St.), Berkeley, CA 94703",
#                 "locality": "Berkeley",
#                 "postcode": "94703",
#                 "region": "CA"
#             },
#             "name": "Las Palmas Super Burritos and Heros",
#             "related_places": {},
#             "timezone": "America/Los_Angeles"
#         },
#         {
#             "fsq_id": "57da76a603a44d3f9b3ddd3b",
#             "categories": [
#                 {
#                     "id": 10004,
#                     "name": "Art Gallery",
#                     "short_name": "Art Gallery",
#                     "plural_name": "Art Galleries",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "chains": [],
#             "closed_bucket": "Unsure",
#             "distance": 100,
#             "geocodes": {
#                 "main": {
#                     "latitude": 37.849798,
#                     "longitude": -122.271728
#                 },
#                 "roof": {
#                     "latitude": 37.849798,
#                     "longitude": -122.271728
#                 }
#             },
#             "link": "/v3/places/57da76a603a44d3f9b3ddd3b",
#             "location": {
#                 "address": "1835 Harmon St",
#                 "census_block": "060014240013000",
#                 "country": "US",
#                 "dma": "San Francisco-Oakland-San Jose",
#                 "formatted_address": "1835 Harmon St, Berkeley, CA 94703",
#                 "locality": "Berkeley",
#                 "postcode": "94703",
#                 "region": "CA"
#             },
#             "name": "Firehouse Collective East/West Art Studios",
#             "related_places": {},
#             "timezone": "America/Los_Angeles"
#         },
#         {
#             "fsq_id": "4b64bd80f964a52074cc2ae3",
#             "categories": [
#                 {
#                     "id": 13064,
#                     "name": "Pizzeria",
#                     "short_name": "Pizza",
#                     "plural_name": "Pizzerias",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/pizza_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "chains": [
#                 {
#                     "id": "ab4afc60-d68a-012e-5619-003048cad9da",
#                     "name": "Domino's Pizza"
#                 }
#             ],
#             "closed_bucket": "VeryLikelyOpen",
#             "distance": 113,
#             "geocodes": {
#                 "main": {
#                     "latitude": 37.849316,
#                     "longitude": -122.271629
#                 },
#                 "roof": {
#                     "latitude": 37.849316,
#                     "longitude": -122.271629
#                 }
#             },
#             "link": "/v3/places/4b64bd80f964a52074cc2ae3",
#             "location": {
#                 "address": "3264 Adeline St",
#                 "census_block": "060014240014000",
#                 "country": "US",
#                 "cross_street": "",
#                 "dma": "San Francisco-Oakland-San Jose",
#                 "formatted_address": "3264 Adeline St, Berkeley, CA 94703",
#                 "locality": "Berkeley",
#                 "postcode": "94703",
#                 "region": "CA"
#             },
#             "name": "Domino's Pizza",
#             "related_places": {},
#             "timezone": "America/Los_Angeles"
#         }
#     ],
#     "context": {
#         "geo_bounds": {
#             "circle": {
#                 "center": {
#                     "latitude": 37.849735,
#                     "longitude": -122.270582
#                 },
#                 "radius": 1000
#             }
#         }
#     }
# }

# %%
res1['results']
# Out:
# [{'fsq_id': '4b3fc82cf964a520a1ae25e3',
#   'categories': [{'id': 13303,
#     'name': 'Mexican Restaurant',
#     'short_name': 'Mexican',
#     'plural_name': 'Mexican Restaurants',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#      'suffix': '.png'}}],
#   'chains': [],
#   'closed_bucket': 'Unsure',
#   'distance': 33,
#   'geocodes': {'main': {'latitude': 37.850052, 'longitude': -122.270523},
#    'roof': {'latitude': 37.850052, 'longitude': -122.270523}},
#   'link': '/v3/places/4b3fc82cf964a520a1ae25e3',
#   'location': {'address': '3221 Adeline St',
#    'census_block': '060014239011019',
#    'country': 'US',
#    'cross_street': 'Alactraz St.',
#    'dma': 'San Francisco-Oakland-San Jose',
#    'formatted_address': '3221 Adeline St (Alactraz St.), Berkeley, CA 94703',
#    'locality': 'Berkeley',
#    'postcode': '94703',
#    'region': 'CA'},
#   'name': 'Las Palmas Super Burritos and Heros',
#   'related_places': {},
#   'timezone': 'America/Los_Angeles'},
#  {'fsq_id': '57da76a603a44d3f9b3ddd3b',
#   'categories': [{'id': 10004,
#     'name': 'Art Gallery',
#     'short_name': 'Art Gallery',
#     'plural_name': 'Art Galleries',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#      'suffix': '.png'}}],
#   'chains': [],
#   'closed_bucket': 'Unsure',
#   'distance': 100,
#   'geocodes': {'main': {'latitude': 37.849798, 'longitude': -122.271728},
#    'roof': {'latitude': 37.849798, 'longitude': -122.271728}},
#   'link': '/v3/places/57da76a603a44d3f9b3ddd3b',
#   'location': {'address': '1835 Harmon St',
#    'census_block': '060014240013000',
#    'country': 'US',
#    'dma': 'San Francisco-Oakland-San Jose',
#    'formatted_address': '1835 Harmon St, Berkeley, CA 94703',
#    'locality': 'Berkeley',
#    'postcode': '94703',
#    'region': 'CA'},
#   'name': 'Firehouse Collective East/West Art Studios',
#   'related_places': {},
#   'timezone': 'America/Los_Angeles'},
#  {'fsq_id': '4b64bd80f964a52074cc2ae3',
#   'categories': [{'id': 13064,
#     'name': 'Pizzeria',
#     'short_name': 'Pizza',
#     'plural_name': 'Pizzerias',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#      'suffix': '.png'}}],
#   'chains': [{'id': 'ab4afc60-d68a-012e-5619-003048cad9da',
#     'name': "Domino's Pizza"}],
#   'closed_bucket': 'VeryLikelyOpen',
#   'distance': 113,
#   'geocodes': {'main': {'latitude': 37.849316, 'longitude': -122.271629},
#    'roof': {'latitude': 37.849316, 'longitude': -122.271629}},
#   'link': '/v3/places/4b64bd80f964a52074cc2ae3',
#   'location': {'address': '3264 Adeline St',
#    'census_block': '060014240014000',
#    'country': 'US',
#    'cross_street': '',
#    'dma': 'San Francisco-Oakland-San Jose',
#    'formatted_address': '3264 Adeline St, Berkeley, CA 94703',
#    'locality': 'Berkeley',
#    'postcode': '94703',
#    'region': 'CA'},
#   'name': "Domino's Pizza",
#   'related_places': {},
#   'timezone': 'America/Los_Angeles'}]

# %%
type(res1['results'])
# Out:
# list

# %%
# fsq_id
res1['results'][0].get('fsq_id', None)
# cat_id
res1['results'][0]['categories'][0].get('id', None)
# cat_name
res1['results'][0]['categories'][0].get('name', None)
# lat
res1['results'][0]['geocodes']['main'].get('latitude', None)
# long
res1['results'][0]['geocodes']['main'].get('longitude', None)
# name
res1['results'][0].get('name', None)
# street address
res1['results'][0]['location'].get('address', None)
# zip
res1['results'][0]['location'].get('postcode', None)
# locality
res1['results'][0]['location'].get('locality', None)
# distance from bike station
res1['results'][0].get('distance', None)
# Out:
# 33

# %%
cols = ['reference_bike_stn', "fsq_id", "cat_id", "cat_name", "lat", "long", "name", "street_address", "zip", "locality", "distance"]
fsq_df = pd.DataFrame(columns=cols)
print(fsq_df)
# Out:
# Empty DataFrame
# Columns: [reference_bike_stn, fsq_id, cat_id, cat_name, lat, long, name, street_address, zip, locality, distance]
# Index: []

# %%
url = 'https://api.foursquare.com/v3/places/search'
params = {'radius': '1000', 'limit': '50', 'categories' : '13000,10000,16000,19042,19043,19046,19050,19054', 'sort' : 'distance'} #13000 is the category label for dining & drinking on foursquare, 10000 =  arts & entertainment, 16000 = landmarks & outdoors, 19042 = bus station, 19043 = bus stop, 19046 = metro station, 19050 = tram station, 19054 = public transportation 
headers = {'Accept': 'application/json', 'Authorization': f'{fsq_api_key}'}

# %%
# fsq_places = fsq_yelp_parsing.get_fsq_places(citybikes_df, url, params,
#                                              headers)

# %%
fsq_places.head(55)
# Out:
#                   reference_bike_stn                    fsq_id  cat_id  \
# 0   d0e8f4f1834b7b33a3faf8882f567ab8  4b3fc82cf964a520a1ae25e3   13303
# 1   d0e8f4f1834b7b33a3faf8882f567ab8  57da76a603a44d3f9b3ddd3b   10004
# 2   d0e8f4f1834b7b33a3faf8882f567ab8  4b64bd80f964a52074cc2ae3   13064
# 3   d0e8f4f1834b7b33a3faf8882f567ab8  4c12e9a51b5cef3b9cd7edc4   13102
# 4   d0e8f4f1834b7b33a3faf8882f567ab8  52fe4532498e80c8d231d768   13034
# 5   d0e8f4f1834b7b33a3faf8882f567ab8  92baf2d6a1c44506a79c620d   10039
# 6   d0e8f4f1834b7b33a3faf8882f567ab8  4ad0dab6f964a52071da20e3   13002
# 7   d0e8f4f1834b7b33a3faf8882f567ab8  4813c2d1f964a5204a4f1fe3   19054
# 8   d0e8f4f1834b7b33a3faf8882f567ab8  57d06497498e691ec2462b97   13039
# 9   d0e8f4f1834b7b33a3faf8882f567ab8  42756d80f964a5207f211fe3   13034
# 10  d0e8f4f1834b7b33a3faf8882f567ab8  4c93ffc2533aa0939247bb45   13099
# 11  d0e8f4f1834b7b33a3faf8882f567ab8  54d0f854498e8535cfd6987e   13034
# 12  d0e8f4f1834b7b33a3faf8882f567ab8  513a7750e4b0dd46fb42027b   16037
# 13  d0e8f4f1834b7b33a3faf8882f567ab8  4fa9c4cce4b01bd551f3bd0d   13064
# 14  d0e8f4f1834b7b33a3faf8882f567ab8  626894eac58d7d640038fe58   13034
# 15  d0e8f4f1834b7b33a3faf8882f567ab8  da3efa0698f345325c17e9ad   13065
# 16  d0e8f4f1834b7b33a3faf8882f567ab8  4bafeee2f964a520922c3ce3   16032
# 17  d0e8f4f1834b7b33a3faf8882f567ab8  4bc6403cf360ef3b346adb2d   13145
# 18  d0e8f4f1834b7b33a3faf8882f567ab8  4e75b5fac65bb91db47bf170   13003
# 19  d0e8f4f1834b7b33a3faf8882f567ab8  4bf9b860508c0f471f973f31   13068
# 20  d0e8f4f1834b7b33a3faf8882f567ab8  4bc14cddf8219c744549b310   10039
# 21  d0e8f4f1834b7b33a3faf8882f567ab8  49cc5e4af964a52070591fe3   13018
# 17                                             Flacos
# 18                                   La Cueva Del Oso
# 19                                    Cafe Valparaiso
# 20                                    Shotgun Players
# 21                                  Starry Plough Pub
# 22                                     Beat the Blues
# 23                               Berkeley Poetry Slam
# 24                            Diverse Community Mural
# 25                                             Shewat
# 26                                 Lois The Pie Queen
# 27                                        Munch India
# 28                                          Creekwood
# 29                            Don Budge Tennis Courts
# 30                                   House Of Curries
# 31                                 Speakeasy Theaters
# 32                                Taqueria La Familia
# 33                                  Emilia's Pizzeria
# 34                                  Dover Street Park
# 35                                       Bushrod Park
# 36                    Center For Environmental Health
# 37  Yurik Riegel - Artist - Best Portraits And Murals
# 38                Art House Gallery & Cultural Center
# 39                                          Taco Bell
# 40                                       Indian Rasoi
# 41                                                KFC
# 42                       Tamales Unicos de Cuernavaca
# 43                                          A+ Burger
# 44                         Addis Ethiopian Restaurant
# 45                       Barcote Ethiopian Restaurant
# 46                                    White Horse Inn
# 47                                       Phosho Dough
# 48                                    Jack In The Box
# 49                                       Goodtime Bar
# 50                                           Miniboss
# 51                           Ike''s Love & Sandwiches
# 52                                          Cash Only
# 53                     Good Karma Artisan Ales & Café
# 54                                        City Bagels
#
#                     street_address    zip  locality  distance
# 0                  3221 Adeline St  94703  Berkeley        33
# 1                   1835 Harmon St  94703  Berkeley       100
# 2                  3264 Adeline St  94703  Berkeley       113
# 3                1818 Alcatraz Ave  94703  Berkeley       119
# 4   3140 Martin Luther King Jr Way  94703  Berkeley       141
# 5                 1802 Fairview St  94703  Berkeley       183
# 6                  3350 Adeline St  94703  Berkeley       275
# 7                  3100 Adeline St  94703  Berkeley       340
# 8                6341 Shattuck Ave  94609   Oakland       409
# 9                6500 Shattuck Ave  94609   Oakland       425
# 10               6336 Shattuck Ave  94609   Oakland       430
# 11                 3051 Adeline St  94703  Berkeley       441
# 12                    1615 63rd St  94703  Berkeley       452
# 13               6211 Shattuck Ave  94609   Oakland       459
# 14               6606 Shattuck Ave  94609   Oakland       467
# 15                    1607 63rd St  94703  Berkeley       481
# 16                  1631 Prince St  94703  Berkeley       493
# 17                 3031 Adeline St  94703  Berkeley       500
# 18                            None  94703  Berkeley       516
# 19               3105 Shattuck Ave  94705  Berkeley       529
# 20                  1901 Ashby Ave  94703  Berkeley       530
# 21               3101 Shattuck Ave  94705  Berkeley       539
# 22               3105 Shattuck Ave  94705  Berkeley       542
# 23               3101 Shattuck Ave  94705  Berkeley       545
# 24               3101 Shattuck Ave  94705  Berkeley       545
# 25               6101 Shattuck Ave  94609   Oakland       554
# 26                     851 60th St  94608   Oakland       583
# 27               3015 Shattuck Ave  94705  Berkeley       668
# 28              3121 Sacramento St  94702  Berkeley       683
# 29               5942 Shattuck Ave  94609   Oakland       702
# 30              3136 Sacramento St  94702  Berkeley       711
# 31                 2218 Woolsey St  94705  Berkeley       730
# 32               2971 Shattuck Ave  94705  Berkeley       735
# 33               2995 Shattuck Ave  94705  Berkeley       737
# 34                   5701 Dover St  94609   Oakland       769
# 35              Racine St and 61st  94609   Oakland       770
# 36                     528 61st St  94609   Oakland       800
# 37               1399 Alcatraz Ave  94702  Berkeley       811
# 38               2905 Shattuck Ave  94705  Berkeley       835
# 39              6035 Telegraph Ave  94609   Oakland       876
# 40              6427 Telegraph Ave  94609   Oakland       877
# 41              6035 Telegraph Ave  94609   Oakland       881
# 42                  5751 Market St  94608   Oakland       885
# 43              6228 Telegraph Ave  94609   Oakland       896
# 44              6100 Telegraph Ave  94609   Oakland       899
# 45              6430 Telegraph Ave  94609   Oakland       906
# 46              6551 Telegraph Ave  94609   Oakland       916
# 47              6601 Telegraph Ave  94609   Oakland       924
# 48              6510 Telegraph Ave  94609   Oakland       941
# 49                 30 Fountain Aly  95113  San Jose        34
# 50             52 E Santa Clara St  95113  San Jose        56
# 51             75 E Santa Clara St  95113  San Jose        75
# 52             78 E Santa Clara St  95113  San Jose        93
# 53                     37 S 1st St  95113  San Jose       107
# 54             52 W Santa Clara St  95113  San Jose       177

# %%
# PICKLE THE COMPLETED FSQ DF 
# with open('../data/fsq_places.pickle', 'wb') as df:
#     pickle.dump(fsq_places, df)

# %%
# UNPICKLE COMPLETED FSQ DF 
with open('../data/fsq_places.pickle', 'rb') as df:
    fsq_places = pickle.load(df)

fsq_places.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25677 entries, 0 to 25676
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   reference_bike_stn  25677 non-null  object
#  1   fsq_id              25677 non-null  object
#  2   cat_id              25677 non-null  int64
#  3   cat_name            25677 non-null  object
#  4   lat                 25677 non-null  float64
#  5   long                25677 non-null  float64
#  6   name                25677 non-null  object
#  7   street_address      24519 non-null  object
#  8   zip                 25657 non-null  object
#  9   locality            25677 non-null  object
#  10  distance            25677 non-null  int64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 2.4+ MB

# %%
url = 'https://api.yelp.com/v3/businesses/search'
categories = 'beaches,bicyclepaths,bowling,rock_climbing,escapegames,hiking,tennis,volleyball,zoos,arcades,galleries,gardens,movietheaters,festivals,museums,trainstations,busstations,metrostations,publictransport,trains,bars,barcrawl,beergardens,karaoke,restaurants'
params = {'latitude': '37.849735', 'longitude' : '-122.270582', 'radius': '1000', 'limit': '3', 'categories' : f'{categories}', 'sort' : 'distance'}
headers = {'Accept': 'application/json', 'Authorization': f'Bearer {yelp_api_key}'}

response = requests.request("GET", url, params=params, headers=headers) # the max limit for results per query is 50, the default is 20
print('status:', response.status_code)
res2 = response.json()
# Out:
# status: 200

# %%
print(json.dumps(res2, indent=4))
# Out:
# {
#     "businesses": [
#         {
#             "id": "OjMumhyL26n5fDZ2CQLnyg",
#             "alias": "lemat-berkeley",
#             "name": "Lemat",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/olmjVKwiGGVBHd771fDnaQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/lemat-berkeley?adjust_creative=YDZxEhaxjqKRlaRTv_Z18A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YDZxEhaxjqKRlaRTv_Z18A",
#             "review_count": 239,
#             "categories": [
#                 {
#                     "alias": "ethiopian",
#                     "title": "Ethiopian"
#                 },
#                 {
#                     "alias": "vegetarian",
#                     "title": "Vegetarian"
#                 },
#                 {
#                     "alias": "gluten_free",
#                     "title": "Gluten-Free"
#                 }
#             ],
#             "rating": 4.4,
#             "coordinates": {
#                 "latitude": 37.850300662973346,
#                 "longitude": -122.27126646102298
#             },
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "3212 Adeline St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Berkeley",
#                 "zip_code": "94703",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "3212 Adeline St",
#                     "Berkeley, CA 94703"
#                 ]
#             },
#             "phone": "+15104302717",
#             "display_phone": "(510) 430-2717",
#             "distance": 86.99355863981393
#         },
#         {
#             "id": "-EpmBwODsvQ6gHx2IuVO5w",
#             "alias": "el-tiny-cafe-berkeley",
#             "name": "El Tiny Cafe",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/tRqsfRFwSLuen9aRsNuXaA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/el-tiny-cafe-berkeley?adjust_creative=YDZxEhaxjqKRlaRTv_Z18A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YDZxEhaxjqKRlaRTv_Z18A",
#             "review_count": 60,
#             "categories": [
#                 {
#                     "alias": "cafes",
#                     "title": "Cafes"
#                 }
#             ],
#             "rating": 4.8,
#             "coordinates": {
#                 "latitude": 37.85001740687401,
#                 "longitude": -122.27053198326358
#             },
#             "transactions": [],
#             "location": {
#                 "address1": "3219 Adeline St",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Berkeley",
#                 "zip_code": "94703",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "3219 Adeline St",
#                     "Berkeley, CA 94703"
#                 ]
#             },
#             "phone": "+15108796945",
#             "display_phone": "(510) 879-6945",
#             "distance": 31.707767038858425
#         },
#         {
#             "id": "shRP4Vxu2hDdmdsHf-5DmQ",
#             "alias": "a-burger-oakland-2",
#             "name": "A+ Burger",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/U5IqS_GLBDFNDK20Nn6upQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/a-burger-oakland-2?adjust_creative=YDZxEhaxjqKRlaRTv_Z18A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YDZxEhaxjqKRlaRTv_Z18A",
#             "review_count": 859,
#             "categories": [
#                 {
#                     "alias": "burgers",
#                     "title": "Burgers"
#                 }
#             ],
#             "rating": 4.4,
#             "coordinates": {
#                 "latitude": 37.84852,
#                 "longitude": -122.26038
#             },
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "6228 Telegraph Ave",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Oakland",
#                 "zip_code": "94609",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "6228 Telegraph Ave",
#                     "Oakland, CA 94609"
#                 ]
#             },
#             "phone": "+15102509598",
#             "display_phone": "(510) 250-9598",
#             "distance": 895.5424159182704
#         }
#     ],
#     "total": 67,
#     "region": {
#         "center": {
#             "longitude": -122.270582,
#             "latitude": 37.849735
#         }
#     }
# }

# %%
res2['businesses'][1]
# Out:
# {'id': '-EpmBwODsvQ6gHx2IuVO5w',
#  'alias': 'el-tiny-cafe-berkeley',
#  'name': 'El Tiny Cafe',
#  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tRqsfRFwSLuen9aRsNuXaA/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/el-tiny-cafe-berkeley?adjust_creative=YDZxEhaxjqKRlaRTv_Z18A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YDZxEhaxjqKRlaRTv_Z18A',
#  'review_count': 60,
#  'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#  'rating': 4.8,
#  'coordinates': {'latitude': 37.85001740687401,
#   'longitude': -122.27053198326358},
#  'transactions': [],
#  'location': {'address1': '3219 Adeline St',
#   'address2': '',
#   'address3': None,
#   'city': 'Berkeley',
#   'zip_code': '94703',
#   'country': 'US',
#   'state': 'CA',
#   'display_address': ['3219 Adeline St', 'Berkeley, CA 94703']},
#  'phone': '+15108796945',
#  'display_phone': '(510) 879-6945',
#  'distance': 31.707767038858425}

# %%
type(res2['businesses'])
# Out:
# list

# %%
# yelp_id
res2['businesses'][0].get('id', None)
# cat_alias
res2['businesses'][0]['categories'][0].get('alias', None)
# latitude
res2['businesses'][0]['coordinates'].get('latitude', None)
# longitude
res2['businesses'][0]['coordinates'].get('longitude', None)
# name
res2['businesses'][0].get('name', None)
# street address
res2['businesses'][0]['location'].get('address1', None)
# zip
res2['businesses'][0]['location'].get('zip_code', None)
# city
res2['businesses'][0]['location'].get('city', None)
# price
res2['businesses'][0].get('price', None)
# rating
res2['businesses'][0].get('rating', None)
# review_count
res2['businesses'][0].get('review_count', None)
# distance
res2['businesses'][0].get('distance', None)
# Out:
# 86.99355863981393

# %%
cols = ["reference_bike_stn", "yelp_id", "cat_alias", "lat", "long", "name", "street_address", "zip", "city", "price", "rating", "review_count", "distance_from_bike_stn"]
yelp_df = pd.DataFrame(columns=cols)
print(yelp_df)
# Out:
# Empty DataFrame
# Columns: [reference_bike_stn, yelp_id, cat_alias, lat, long, name, street_address, zip, city, price, rating, review_count, distance_from_bike_stn]
# Index: []

# %%
url = 'https://api.yelp.com/v3/businesses/search'
categories = 'beaches,bicyclepaths,bowling,rock_climbing,escapegames,hiking,tennis,volleyball,zoos,arcades,galleries,gardens,movietheaters,festivals,museums,trainstations,busstations,metrostations,publictransport,trains,bars,barcrawl,beergardens,karaoke,restaurants'
params = {'radius': '1000', 'limit': '50', 'categories' : f'{categories}', 'sort' : 'distance'}
headers = {'Accept': 'application/json', 'Authorization': f'Bearer {yelp_api_key}'}

# %%
# yelp_df = fsq_yelp_parsing.get_yelp_places(citybikes_df, url, params, headers)

# %%
yelp_df.head(55)
# Out:
#                   reference_bike_stn                 yelp_id  \
# 0   d0e8f4f1834b7b33a3faf8882f567ab8  OjMumhyL26n5fDZ2CQLnyg
# 1   d0e8f4f1834b7b33a3faf8882f567ab8  -EpmBwODsvQ6gHx2IuVO5w
# 2   d0e8f4f1834b7b33a3faf8882f567ab8  shRP4Vxu2hDdmdsHf-5DmQ
# 3   d0e8f4f1834b7b33a3faf8882f567ab8  pJdwr6JoCVXTKbdJlm-rdg
# 4   d0e8f4f1834b7b33a3faf8882f567ab8  nt46Amrqx5qwTyNEcO54ew
# 5   d0e8f4f1834b7b33a3faf8882f567ab8  D2wNghkuR1c9t0teBNEkeA
# 6   d0e8f4f1834b7b33a3faf8882f567ab8  2pkjzIZov1W5KfvbCb1qWQ
# 7   d0e8f4f1834b7b33a3faf8882f567ab8  xVIBJ9IzKj3W8mbG72ZYbw
# 8   d0e8f4f1834b7b33a3faf8882f567ab8  _pnL-cS9nBLKkDXFX1PEQw
# 9   d0e8f4f1834b7b33a3faf8882f567ab8  j1bcEu0iTxs-dnu_hri3Pw
# 10  d0e8f4f1834b7b33a3faf8882f567ab8  eYjmfE1N6Xn-bmqU041trg
# 11  d0e8f4f1834b7b33a3faf8882f567ab8  zdczn9hGEI0gBMHGsTy8Bw
# 12  d0e8f4f1834b7b33a3faf8882f567ab8  LP6NBMIa3dxinjgtOxMEZg
# 13  d0e8f4f1834b7b33a3faf8882f567ab8  6j8n9b24TVJ5f5-M5MsWJw
# 14  d0e8f4f1834b7b33a3faf8882f567ab8  t4vry3wdjfVhylCHAIVq1A
# 15  d0e8f4f1834b7b33a3faf8882f567ab8  7UVX5pvSaAu_ILLIkX6Wog
# 16  d0e8f4f1834b7b33a3faf8882f567ab8  guObf4lR-TsRD1IHJni06g
# 17  d0e8f4f1834b7b33a3faf8882f567ab8  lcgcmgrrFVWuHmeTsWNd5w
# 18  d0e8f4f1834b7b33a3faf8882f567ab8  4TkFHxPeQxf0ORGZoSqUww
# 4    Oakland    $$     4.4           496              853.805062
# 5    Oakland    $$     4.9           264              541.695667
# 6   Berkeley  None     4.9            36              176.383198
# 7   Berkeley     $     4.7           209              172.510512
# 8   Berkeley    $$     4.3           451             1082.621576
# 9    Oakland    $$     4.4           430              928.747028
# 10   Oakland    $$     4.3           515              461.851209
# 11  Berkeley  None     3.8            59              147.549732
# 12  Berkeley    $$     3.9           197               29.930556
# 13   Oakland  None     4.7           171              470.122509
# 14   Oakland    $$     4.0          1207              589.729990
# 15  Berkeley    $$     4.2           243              537.411953
# 16  Berkeley    $$     3.4           359               97.503704
# 17   Oakland    $$     4.2           688              913.319031
# 18  Berkeley     $     4.6           186              742.230508
# 19  Berkeley    $$     4.1           392              538.151750
# 20  Berkeley    $$     4.5           451              747.157953
# 21   Oakland    $$     4.6           285              917.088604
# 22  Berkeley     $     3.5            90              119.831755
# 23   Oakland    $$     4.5           111              879.992213
# 24  Berkeley    $$     4.0           456             1052.869591
# 25   Oakland    $$     3.8           330              439.370660
# 26  Berkeley     $     4.5           150              446.227578
# 27   Oakland    $$     4.2           431              893.708331
# 28   Oakland  None     4.5            47              872.812812
# 29  Berkeley     $     3.7           657             1020.990562
# 30  Berkeley     $     4.0           412              760.081542
# 31   Oakland     $     4.4           162              887.437375
# 32  Berkeley    $$     3.8           564             1262.641927
# 33  Berkeley     $     4.0             7              130.904905
# 34  Berkeley  None     4.5            73              671.339889
# 35  Berkeley     $     1.6           175              100.420369
# 36   Oakland  None     4.5           103             1014.772006
# 37  Berkeley  None     4.2            22              722.869022
# 38  Berkeley     $     3.9            28              346.653775
# 39  Berkeley     $     4.5            13              336.951920
# 40   Oakland     $     3.7            57              448.375860
# 41  Berkeley  None     5.0             1              103.233701
# 42  Berkeley    $$     3.5            68             1220.500442
# 43  Berkeley     $     5.0             2              210.557649
# 44  Berkeley  None     2.8            58              371.649999
# 45   Oakland    $$     5.0             4             1024.421733
# 46  Berkeley  None     4.1            20              765.678357
# 47  Berkeley  None     4.0             2              127.538357
# 48   Oakland     $     3.6           263              911.697665
# 49   Oakland  None     4.2             5              645.143088
# 50  San Jose    $$     4.9            85               34.370789
# 51  San Jose    $$     4.3          1275               57.455383
# 52  San Jose    $$     4.1          1584              131.544220
# 53  San Jose    $$     4.9            80               57.937561
# 54  San Jose    $$     4.1           746              134.780089

# %%
# with open('../data/yelp_df.pickle', 'wb') as df:
#     pickle.dump(yelp_df, df)

# %%
# UNPICKLE YELP DF 
with open('../data/yelp_df.pickle', 'rb') as df:
    yelp_df = pickle.load(df)

yelp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27315 entries, 0 to 27314
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   reference_bike_stn      27315 non-null  object
#  1   yelp_id                 27315 non-null  object
#  2   cat_alias               27315 non-null  object
#  3   lat                     27315 non-null  float64
#  4   long                    27315 non-null  float64
#  5   name                    27315 non-null  object
#  6   street_address          27202 non-null  object
#  7   zip                     27315 non-null  object
#  8   city                    27315 non-null  object
#  9   price                   23520 non-null  object
#  10  rating                  27315 non-null  float64
#  11  review_count            27315 non-null  int64
#  12  distance_from_bike_stn  27315 non-null  float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 2.9+ MB
